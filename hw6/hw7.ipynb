# %% [markdown]
# ## Introduction
#
# This is a homework for 6-7 weeks

# %% [markdown]
# Importing libraries:

# %%
import numpy as np # used for handling numbers
import pandas as pd

from sklearn.impute import SimpleImputer # used for handling missing data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder # used for encoding categorical data
from sklearn.model_selection import train_test_split # used for splitting training and testing data
from sklearn.preprocessing import StandardScaler # used for feature scaling

# %% [markdown]
# Importing the 'xlsx' document as a pandas data frame:

# %%
df = pd.read_excel('car_sells.xlsx')
df.shape
# Out:
# (372, 14)

# %%
df
# Out:
#           Brand          Name  Year     Price Currency    Город        Кузов  \
# 0    ВАЗ (Lada)        Largus  2013   3100000        ₸  Шымкент    универсал
# 1        Daewoo         Nexia  2012   2100000        ₸  Шымкент        седан
# 2    Mitsubishi     Outlander  2013   6500000        ₸  Шымкент    кроссовер
# 3           УАЗ        Hunter  2017   4500000        ₸  Шымкент  внедорожник
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        ₸  Шымкент        седан
# ..          ...           ...   ...       ...      ...      ...          ...
# 367      Toyota         Camry  2017  13000000        ₸  Шымкент        седан
# 368       Ravon            R4  2017   4250000        ₸  Шымкент        седан
# 369     Hyundai       Solaris  2011   2900000        ₸  Шымкент        седан
# 370     Renault        Kaptur  2020   9796000        ₸  Шымкент    кроссовер
# 371         Kia      Carnival  2020  21500000        ₸  Шымкент      минивэн
#
#     Объем двигателя, л      Пробег Коробка передач   Руль  \
# 0     1.6 (газ-бензин)         NaN        механика  слева
# 1         1.6 (бензин)  141 000 км        механика  слева
# 2         2.4 (бензин)  100 375 км         автомат  слева
# 3         2.7 (бензин)   55 000 км        механика  слева
# 4         1.6 (бензин)   23 500 км        механика  слева
# ..                 ...         ...             ...    ...
# 367       2.5 (бензин)  139 000 км         автомат  слева
# 368       1.5 (бензин)   49 500 км        механика  слева
# 369       1.4 (бензин)  170 000 км         автомат  слева
# 370       1.6 (бензин)         NaN        механика  слева
# 371       2.2 (дизель)    1 880 км         автомат  слева
#
#                      Цвет           Привод Растаможен в Казахстане
# 0                   белый  передний привод                      Да
# 1    серебристый металлик  передний привод                      Да
# 2         черный металлик    полный привод                      Да
# 3                     NaN    полный привод                      Да
# 4    серебристый металлик  передний привод                      Да
# ..                    ...              ...                     ...
# 367        белый металлик  передний привод                      Да
# 368        белый металлик  передний привод                      Да
# 369        серый металлик  передний привод                     Нет
# 370                   NaN  передний привод                      Да
# 371       черный металлик  передний привод                      Да
#
# [372 rows x 14 columns]

# %% [markdown]
# Some cleaning operations going on:

# %%
df[['Объем двигателя, л', 'Топливо']] = df['Объем двигателя, л'].str.split(' ', expand=True)

df['Топливо'] = df['Топливо'].str.replace('(', '')
df['Топливо'] = df['Топливо'].str.replace(')', '')

df
# Out:
#           Brand          Name  Year     Price Currency    Город        Кузов  \
# 0    ВАЗ (Lada)        Largus  2013   3100000        ₸  Шымкент    универсал
# 1        Daewoo         Nexia  2012   2100000        ₸  Шымкент        седан
# 2    Mitsubishi     Outlander  2013   6500000        ₸  Шымкент    кроссовер
# 3           УАЗ        Hunter  2017   4500000        ₸  Шымкент  внедорожник
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        ₸  Шымкент        седан
# ..          ...           ...   ...       ...      ...      ...          ...
# 367      Toyota         Camry  2017  13000000        ₸  Шымкент        седан
# 368       Ravon            R4  2017   4250000        ₸  Шымкент        седан
# 369     Hyundai       Solaris  2011   2900000        ₸  Шымкент        седан
# 370     Renault        Kaptur  2020   9796000        ₸  Шымкент    кроссовер
# 371         Kia      Carnival  2020  21500000        ₸  Шымкент      минивэн
#
#     Объем двигателя, л      Пробег Коробка передач   Руль  \
# 0                  1.6         NaN        механика  слева
# 1                  1.6  141 000 км        механика  слева
# 2                  2.4  100 375 км         автомат  слева
# 3                  2.7   55 000 км        механика  слева
# 4                  1.6   23 500 км        механика  слева
# ..                 ...         ...             ...    ...
# 367                2.5  139 000 км         автомат  слева
# 368                1.5   49 500 км        механика  слева
# 369                1.4  170 000 км         автомат  слева
# 370                1.6         NaN        механика  слева
# 371                2.2    1 880 км         автомат  слева
#
#                      Цвет           Привод Растаможен в Казахстане     Топливо
# 0                   белый  передний привод                      Да  газ-бензин
# 1    серебристый металлик  передний привод                      Да      бензин
# 2         черный металлик    полный привод                      Да      бензин
# 3                     NaN    полный привод                      Да      бензин
# 4    серебристый металлик  передний привод                      Да      бензин
# ..                    ...              ...                     ...         ...
# 367        белый металлик  передний привод                      Да      бензин
# 368        белый металлик  передний привод                      Да      бензин
# 369        серый металлик  передний привод                     Нет      бензин
# 370                   NaN  передний привод                      Да      бензин
# 371       черный металлик  передний привод                      Да      дизель
#
# [372 rows x 15 columns]

# %% [markdown]
# And so, cleaning, shaping and etc...:

# %%
df['Пробег'] = df['Пробег'].str.replace(' км', '')
df
# Out:
#           Brand          Name  Year     Price Currency    Город        Кузов  \
# 0    ВАЗ (Lada)        Largus  2013   3100000        ₸  Шымкент    универсал
# 1        Daewoo         Nexia  2012   2100000        ₸  Шымкент        седан
# 2    Mitsubishi     Outlander  2013   6500000        ₸  Шымкент    кроссовер
# 3           УАЗ        Hunter  2017   4500000        ₸  Шымкент  внедорожник
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        ₸  Шымкент        седан
# ..          ...           ...   ...       ...      ...      ...          ...
# 367      Toyota         Camry  2017  13000000        ₸  Шымкент        седан
# 368       Ravon            R4  2017   4250000        ₸  Шымкент        седан
# 369     Hyundai       Solaris  2011   2900000        ₸  Шымкент        седан
# 370     Renault        Kaptur  2020   9796000        ₸  Шымкент    кроссовер
# 371         Kia      Carnival  2020  21500000        ₸  Шымкент      минивэн
#
#     Объем двигателя, л   Пробег Коробка передач   Руль                  Цвет  \
# 0                  1.6      NaN        механика  слева                 белый
# 1                  1.6  141 000        механика  слева  серебристый металлик
# 2                  2.4  100 375         автомат  слева       черный металлик
# 3                  2.7   55 000        механика  слева                   NaN
# 4                  1.6   23 500        механика  слева  серебристый металлик
# ..                 ...      ...             ...    ...                   ...
# 367                2.5  139 000         автомат  слева        белый металлик
# 368                1.5   49 500        механика  слева        белый металлик
# 369                1.4  170 000         автомат  слева        серый металлик
# 370                1.6      NaN        механика  слева                   NaN
# 371                2.2    1 880         автомат  слева       черный металлик
#
#               Привод Растаможен в Казахстане     Топливо
# 0    передний привод                      Да  газ-бензин
# 1    передний привод                      Да      бензин
# 2      полный привод                      Да      бензин
# 3      полный привод                      Да      бензин
# 4    передний привод                      Да      бензин
# ..               ...                     ...         ...
# 367  передний привод                      Да      бензин
# 368  передний привод                      Да      бензин
# 369  передний привод                     Нет      бензин
# 370  передний привод                      Да      бензин
# 371  передний привод                      Да      дизель
#
# [372 rows x 15 columns]

# %% [markdown]
# Deleting columns that wouldn't be used in this task:

# %%
del df['Город']
del df['Currency']
del df['Цвет']

df
# Out:
#           Brand          Name  Year     Price        Кузов Объем двигателя, л  \
# 0    ВАЗ (Lada)        Largus  2013   3100000    универсал                1.6
# 1        Daewoo         Nexia  2012   2100000        седан                1.6
# 2    Mitsubishi     Outlander  2013   6500000    кроссовер                2.4
# 3           УАЗ        Hunter  2017   4500000  внедорожник                2.7
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        седан                1.6
# ..          ...           ...   ...       ...          ...                ...
# 367      Toyota         Camry  2017  13000000        седан                2.5
# 368       Ravon            R4  2017   4250000        седан                1.5
# 369     Hyundai       Solaris  2011   2900000        седан                1.4
# 370     Renault        Kaptur  2020   9796000    кроссовер                1.6
# 371         Kia      Carnival  2020  21500000      минивэн                2.2
#
#       Пробег Коробка передач   Руль           Привод Растаможен в Казахстане  \
# 0        NaN        механика  слева  передний привод                      Да
# 1    141 000        механика  слева  передний привод                      Да
# 2    100 375         автомат  слева    полный привод                      Да
# 3     55 000        механика  слева    полный привод                      Да
# 4     23 500        механика  слева  передний привод                      Да
# ..       ...             ...    ...              ...                     ...
# 367  139 000         автомат  слева  передний привод                      Да
# 368   49 500        механика  слева  передний привод                      Да
# 369  170 000         автомат  слева  передний привод                     Нет
# 370      NaN        механика  слева  передний привод                      Да
# 371    1 880         автомат  слева  передний привод                      Да
#
#         Топливо
# 0    газ-бензин
# 1        бензин
# 2        бензин
# 3        бензин
# 4        бензин
# ..          ...
# 367      бензин
# 368      бензин
# 369      бензин
# 370      бензин
# 371      дизель
#
# [372 rows x 12 columns]

# %% [markdown]
# Fixing and Removing NaN values in Data Set:

# %%
df.replace('NaN', 'null')
df.replace('null', np.nan)
# Out:
#           Brand          Name  Year     Price        Кузов Объем двигателя, л  \
# 0    ВАЗ (Lada)        Largus  2013   3100000    универсал                1.6
# 1        Daewoo         Nexia  2012   2100000        седан                1.6
# 2    Mitsubishi     Outlander  2013   6500000    кроссовер                2.4
# 3           УАЗ        Hunter  2017   4500000  внедорожник                2.7
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        седан                1.6
# ..          ...           ...   ...       ...          ...                ...
# 367      Toyota         Camry  2017  13000000        седан                2.5
# 368       Ravon            R4  2017   4250000        седан                1.5
# 369     Hyundai       Solaris  2011   2900000        седан                1.4
# 370     Renault        Kaptur  2020   9796000    кроссовер                1.6
# 371         Kia      Carnival  2020  21500000      минивэн                2.2
#
#       Пробег Коробка передач   Руль           Привод Растаможен в Казахстане  \
# 0        NaN        механика  слева  передний привод                      Да
# 1    141 000        механика  слева  передний привод                      Да
# 2    100 375         автомат  слева    полный привод                      Да
# 3     55 000        механика  слева    полный привод                      Да
# 4     23 500        механика  слева  передний привод                      Да
# ..       ...             ...    ...              ...                     ...
# 367  139 000         автомат  слева  передний привод                      Да
# 368   49 500        механика  слева  передний привод                      Да
# 369  170 000         автомат  слева  передний привод                     Нет
# 370      NaN        механика  слева  передний привод                      Да
# 371    1 880         автомат  слева  передний привод                      Да
#
#         Топливо
# 0    газ-бензин
# 1        бензин
# 2        бензин
# 3        бензин
# 4        бензин
# ..          ...
# 367      бензин
# 368      бензин
# 369      бензин
# 370      бензин
# 371      дизель
#
# [372 rows x 12 columns]

# %%
df = df.dropna()
df
# Out:
#           Brand          Name  Year     Price        Кузов Объем двигателя, л  \
# 1        Daewoo         Nexia  2012   2100000        седан                1.6
# 2    Mitsubishi     Outlander  2013   6500000    кроссовер                2.4
# 3           УАЗ        Hunter  2017   4500000  внедорожник                2.7
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        седан                1.6
# 5        Nissan        Almera  2018   4600000        седан                1.6
# ..          ...           ...   ...       ...          ...                ...
# 363  ВАЗ (Lada)  2190 (седан)  2013   1800000        седан                1.6
# 367      Toyota         Camry  2017  13000000        седан                2.5
# 368       Ravon            R4  2017   4250000        седан                1.5
# 369     Hyundai       Solaris  2011   2900000        седан                1.4
# 371         Kia      Carnival  2020  21500000      минивэн                2.2
#
#       Пробег Коробка передач   Руль           Привод Растаможен в Казахстане  \
# 1    141 000        механика  слева  передний привод                      Да
# 2    100 375         автомат  слева    полный привод                      Да
# 3     55 000        механика  слева    полный привод                      Да
# 4     23 500        механика  слева  передний привод                      Да
# 5     60 908         автомат  слева  передний привод                      Да
# ..       ...             ...    ...              ...                     ...
# 363  169 999        механика  слева  передний привод                      Да
# 367  139 000         автомат  слева  передний привод                      Да
# 368   49 500        механика  слева  передний привод                      Да
# 369  170 000         автомат  слева  передний привод                     Нет
# 371    1 880         автомат  слева  передний привод                      Да
#
#     Топливо
# 1    бензин
# 2    бензин
# 3    бензин
# 4    бензин
# 5    бензин
# ..      ...
# 363  бензин
# 367  бензин
# 368  бензин
# 369  бензин
# 371  дизель
#
# [257 rows x 12 columns]

# %%
df.describe()
# Out:
#               Year         Price
# count   257.000000  2.570000e+02
# mean   2015.385214  8.954910e+06
# std       2.983590  7.700214e+06
# min    2010.000000  6.800000e+05
# 25%    2013.000000  3.900000e+06
# 50%    2015.000000  6.800000e+06
# 75%    2018.000000  1.150000e+07
# max    2021.000000  4.800000e+07

# %% [markdown]
# Working with data types:

# %%
df.dtypes
# Out:
# Brand                      object
# Name                       object
# Year                        int64
# Price                       int64
# Кузов                      object
# Объем двигателя, л         object
# Пробег                     object
# Коробка передач            object
# Руль                       object
# Привод                     object
# Растаможен в Казахстане    object
# Топливо                    object
# dtype: object

# %%
df['Объем двигателя, л'] = df['Объем двигателя, л'].astype('float')

df['Пробег'] = df['Пробег'].str.replace(' ', '')
df['Пробег'] = df['Пробег'].astype('float')

df.dtypes
# Out:
# <ipython-input-11-fecfba755a0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Объем двигателя, л'] = df['Объем двигателя, л'].astype('float')
# <ipython-input-11-fecfba755a0a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Пробег'] = df['Пробег'].str.replace(' ', '')
# <ipython-input-11-fecfba755a0a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Пробег'] = df['Пробег'].astype('float')
# Brand                       object
# Name                        object
# Year                         int64
# Price                        int64
# Кузов                       object
# Объем двигателя, л         float64
# Пробег                     float64
# Коробка передач             object
# Руль                        object
# Привод                      object
# Растаможен в Казахстане     object
# Топливо                     object
# dtype: object

# %%
df
# Out:
#           Brand          Name  Year     Price        Кузов  \
# 1        Daewoo         Nexia  2012   2100000        седан
# 2    Mitsubishi     Outlander  2013   6500000    кроссовер
# 3           УАЗ        Hunter  2017   4500000  внедорожник
# 4    ВАЗ (Lada)  2190 (седан)  2018   3650000        седан
# 5        Nissan        Almera  2018   4600000        седан
# ..          ...           ...   ...       ...          ...
# 363  ВАЗ (Lada)  2190 (седан)  2013   1800000        седан
# 367      Toyota         Camry  2017  13000000        седан
# 368       Ravon            R4  2017   4250000        седан
# 369     Hyundai       Solaris  2011   2900000        седан
# 371         Kia      Carnival  2020  21500000      минивэн
#
#      Объем двигателя, л    Пробег Коробка передач   Руль           Привод  \
# 1                   1.6  141000.0        механика  слева  передний привод
# 2                   2.4  100375.0         автомат  слева    полный привод
# 3                   2.7   55000.0        механика  слева    полный привод
# 4                   1.6   23500.0        механика  слева  передний привод
# 5                   1.6   60908.0         автомат  слева  передний привод
# ..                  ...       ...             ...    ...              ...
# 363                 1.6  169999.0        механика  слева  передний привод
# 367                 2.5  139000.0         автомат  слева  передний привод
# 368                 1.5   49500.0        механика  слева  передний привод
# 369                 1.4  170000.0         автомат  слева  передний привод
# 371                 2.2    1880.0         автомат  слева  передний привод
#
#     Растаможен в Казахстане Топливо
# 1                        Да  бензин
# 2                        Да  бензин
# 3                        Да  бензин
# 4                        Да  бензин
# 5                        Да  бензин
# ..                      ...     ...
# 363                      Да  бензин
# 367                      Да  бензин
# 368                      Да  бензин
# 369                     Нет  бензин
# 371                      Да  дизель
#
# [257 rows x 12 columns]

# %% [markdown]
# Actually, here were some operations like removing columns that wouldn't be used, but it seems that I have deleted the code:

# %%
df_copy = df

df.describe()
# Out:
#               Year         Price  Объем двигателя, л        Пробег
# count   257.000000  2.570000e+02          257.000000  2.570000e+02
# mean   2015.385214  8.954910e+06            2.125549  8.780179e+04
# std       2.983590  7.700214e+06            0.879282  9.157975e+04
# min    2010.000000  6.800000e+05            0.800000  5.000000e+00
# 25%    2013.000000  3.900000e+06            1.600000  2.820000e+04
# 50%    2015.000000  6.800000e+06            2.000000  8.453000e+04
# 75%    2018.000000  1.150000e+07            2.500000  1.250000e+05
# max    2021.000000  4.800000e+07            6.300000  1.174411e+06

# %%
del df['Name']
del df['Руль']
del df['Коробка передач']
del df['Привод']
del df['Растаможен в Казахстане']

df
# Out:
#           Brand  Year     Price        Кузов  Объем двигателя, л    Пробег  \
# 1        Daewoo  2012   2100000        седан                 1.6  141000.0
# 2    Mitsubishi  2013   6500000    кроссовер                 2.4  100375.0
# 3           УАЗ  2017   4500000  внедорожник                 2.7   55000.0
# 4    ВАЗ (Lada)  2018   3650000        седан                 1.6   23500.0
# 5        Nissan  2018   4600000        седан                 1.6   60908.0
# ..          ...   ...       ...          ...                 ...       ...
# 363  ВАЗ (Lada)  2013   1800000        седан                 1.6  169999.0
# 367      Toyota  2017  13000000        седан                 2.5  139000.0
# 368       Ravon  2017   4250000        седан                 1.5   49500.0
# 369     Hyundai  2011   2900000        седан                 1.4  170000.0
# 371         Kia  2020  21500000      минивэн                 2.2    1880.0
#
#     Топливо
# 1    бензин
# 2    бензин
# 3    бензин
# 4    бензин
# 5    бензин
# ..      ...
# 363  бензин
# 367  бензин
# 368  бензин
# 369  бензин
# 371  дизель
#
# [257 rows x 7 columns]

# %% [markdown]
# Doing some operations for encoding the object/string types:

# %%
df['Кузов'].describe()
# Out:
# count       257
# unique       11
# top       седан
# freq        163
# Name: Кузов, dtype: object

# %%
df['Brand'].describe()
df['Brand'].unique()
# Out:
# array(['Daewoo', 'Mitsubishi', 'УАЗ', 'ВАЗ (Lada)', 'Nissan', 'Toyota',
#        'Hyundai', 'Ravon', 'Lexus', 'ГАЗ', 'Kia', 'Mercedes-Benz',
#        'Chevrolet', 'Volkswagen', 'BMW', 'Land Rover', 'Renault Samsung',
#        'FAW', 'Audi', 'Lifan', 'Renault', 'Mazda', 'Skoda', 'Honda',
#        'JAC', 'Maserati', 'ТагАЗ'], dtype=object)

# %%
df['Топливо'] = df['Топливо'].astype('category')
df.dtypes
# Out:
# <ipython-input-31-a9f387cfd9e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Топливо'] = df['Топливо'].astype('category')
# Brand                   object
# Year                     int64
# Price                    int64
# Кузов                   object
# Объем двигателя, л     float64
# Пробег                 float64
# Топливо               category
# dtype: object

# %%
df['Fuel'] = df['Топливо'].cat.codes
df
# Out:
# <ipython-input-32-a9c2d0cbe773>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fuel'] = df['Топливо'].cat.codes
#           Brand  Year     Price        Кузов  Объем двигателя, л    Пробег  \
# 1        Daewoo  2012   2100000        седан                 1.6  141000.0
# 2    Mitsubishi  2013   6500000    кроссовер                 2.4  100375.0
# 3           УАЗ  2017   4500000  внедорожник                 2.7   55000.0
# 4    ВАЗ (Lada)  2018   3650000        седан                 1.6   23500.0
# 5        Nissan  2018   4600000        седан                 1.6   60908.0
# ..          ...   ...       ...          ...                 ...       ...
# 363  ВАЗ (Lada)  2013   1800000        седан                 1.6  169999.0
# 367      Toyota  2017  13000000        седан                 2.5  139000.0
# 368       Ravon  2017   4250000        седан                 1.5   49500.0
# 369     Hyundai  2011   2900000        седан                 1.4  170000.0
# 371         Kia  2020  21500000      минивэн                 2.2    1880.0
#
#     Топливо  Fuel
# 1    бензин     0
# 2    бензин     0
# 3    бензин     0
# 4    бензин     0
# 5    бензин     0
# ..      ...   ...
# 363  бензин     0
# 367  бензин     0
# 368  бензин     0
# 369  бензин     0
# 371  дизель     3
#
# [257 rows x 8 columns]

# %% [markdown]
# 0 - Benzin
#
# 1 - Gas
#
# 2 - Gas-Benzin
#
# 3 - Dizel

# %%
df2_copy = df

# %%
df = df2_copy

#del df['Топливо']

#df['Body'] = np.where(df['Кузов'].str.contains('седан'), 1, 0)

df
# Out:
#           Brand  Year     Price  Объем двигателя, л    Пробег  Fuel  Body
# 1        Daewoo  2012   2100000                 1.6  141000.0     0     1
# 2    Mitsubishi  2013   6500000                 2.4  100375.0     0     0
# 3           УАЗ  2017   4500000                 2.7   55000.0     0     0
# 4    ВАЗ (Lada)  2018   3650000                 1.6   23500.0     0     1
# 5        Nissan  2018   4600000                 1.6   60908.0     0     1
# ..          ...   ...       ...                 ...       ...   ...   ...
# 363  ВАЗ (Lada)  2013   1800000                 1.6  169999.0     0     1
# 367      Toyota  2017  13000000                 2.5  139000.0     0     1
# 368       Ravon  2017   4250000                 1.5   49500.0     0     1
# 369     Hyundai  2011   2900000                 1.4  170000.0     0     1
# 371         Kia  2020  21500000                 2.2    1880.0     3     0
#
# [257 rows x 7 columns]

# %% [markdown]
# 0 - Not a sedan
#
# 1 - Sedan

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
df['brnd'] = ord_enc.fit_transform(df[['Brand']])
df
# Out:
# <ipython-input-53-879c5749fcec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['brnd'] = ord_enc.fit_transform(df[['Brand']])
#           Brand  Year     Price  Объем двигателя, л    Пробег  Fuel  Body  \
# 1        Daewoo  2012   2100000                 1.6  141000.0     0     1
# 2    Mitsubishi  2013   6500000                 2.4  100375.0     0     0
# 3           УАЗ  2017   4500000                 2.7   55000.0     0     0
# 4    ВАЗ (Lada)  2018   3650000                 1.6   23500.0     0     1
# 5        Nissan  2018   4600000                 1.6   60908.0     0     1
# ..          ...   ...       ...                 ...       ...   ...   ...
# 363  ВАЗ (Lada)  2013   1800000                 1.6  169999.0     0     1
# 367      Toyota  2017  13000000                 2.5  139000.0     0     1
# 368       Ravon  2017   4250000                 1.5   49500.0     0     1
# 369     Hyundai  2011   2900000                 1.4  170000.0     0     1
# 371         Kia  2020  21500000                 2.2    1880.0     3     0
#
#      brnd
# 1     3.0
# 2    15.0
# 3    26.0
# 4    23.0
# 5    16.0
# ..    ...
# 363  23.0
# 367  21.0
# 368  17.0
# 369   6.0
# 371   8.0
#
# [257 rows x 8 columns]

# %%
pd.concat([df['Brand'], df['brnd']]).unique()
# Out:
# array(['Daewoo', 'Mitsubishi', 'УАЗ', 'ВАЗ (Lada)', 'Nissan', 'Toyota',
#        'Hyundai', 'Ravon', 'Lexus', 'ГАЗ', 'Kia', 'Mercedes-Benz',
#        'Chevrolet', 'Volkswagen', 'BMW', 'Land Rover', 'Renault Samsung',
#        'FAW', 'Audi', 'Lifan', 'Renault', 'Mazda', 'Skoda', 'Honda',
#        'JAC', 'Maserati', 'ТагАЗ', 3.0, 15.0, 26.0, 23.0, 16.0, 21.0, 6.0,
#        17.0, 10.0, 24.0, 8.0, 14.0, 2.0, 22.0, 1.0, 9.0, 19.0, 4.0, 0.0,
#        11.0, 18.0, 13.0, 20.0, 5.0, 7.0, 12.0, 25.0], dtype=object)

# %%
df3 = df
df3
# Out:
#           Brand  Year     Price  Объем двигателя, л    Пробег  Fuel  Body  \
# 1        Daewoo  2012   2100000                 1.6  141000.0     0     1
# 2    Mitsubishi  2013   6500000                 2.4  100375.0     0     0
# 3           УАЗ  2017   4500000                 2.7   55000.0     0     0
# 4    ВАЗ (Lada)  2018   3650000                 1.6   23500.0     0     1
# 5        Nissan  2018   4600000                 1.6   60908.0     0     1
# ..          ...   ...       ...                 ...       ...   ...   ...
# 363  ВАЗ (Lada)  2013   1800000                 1.6  169999.0     0     1
# 367      Toyota  2017  13000000                 2.5  139000.0     0     1
# 368       Ravon  2017   4250000                 1.5   49500.0     0     1
# 369     Hyundai  2011   2900000                 1.4  170000.0     0     1
# 371         Kia  2020  21500000                 2.2    1880.0     3     0
#
#      brnd
# 1     3.0
# 2    15.0
# 3    26.0
# 4    23.0
# 5    16.0
# ..    ...
# 363  23.0
# 367  21.0
# 368  17.0
# 369   6.0
# 371   8.0
#
# [257 rows x 8 columns]

# %%
del df['Brand']
df
# Out:
#      Year     Price  Объем двигателя, л    Пробег  Fuel  Body  brnd
# 1    2012   2100000                 1.6  141000.0     0     1   3.0
# 2    2013   6500000                 2.4  100375.0     0     0  15.0
# 3    2017   4500000                 2.7   55000.0     0     0  26.0
# 4    2018   3650000                 1.6   23500.0     0     1  23.0
# 5    2018   4600000                 1.6   60908.0     0     1  16.0
# ..    ...       ...                 ...       ...   ...   ...   ...
# 363  2013   1800000                 1.6  169999.0     0     1  23.0
# 367  2017  13000000                 2.5  139000.0     0     1  21.0
# 368  2017   4250000                 1.5   49500.0     0     1  17.0
# 369  2011   2900000                 1.4  170000.0     0     1   6.0
# 371  2020  21500000                 2.2    1880.0     3     0   8.0
#
# [257 rows x 7 columns]

# %% [markdown]
# Now, after finishing previous operation, I am going to work with train and test sets:

# %%
y = df.Price

x = df.drop('Price', axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

reg = linear_model.LinearRegression()

# %%
print("shape of original dataset :", df.shape)
print("shape of input - training set", x_train.shape)
print("shape of output - training set", y_train.shape)
print("shape of input - testing set", x_test.shape)
print("shape of output - testing set", y_test.shape)
# Out:
# shape of original dataset : (257, 7)
# shape of input - training set (205, 6)
# shape of output - training set (205,)
# shape of input - testing set (52, 6)
# shape of output - testing set (52,)

# %%
reg.score(x_test, y_test)
# Out:
# 0.6355199229563386

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
df_scaled = pd.DataFrame(sc.fit_transform(df), columns=df.columns)

# %%
y2 = df_scaled.Price

x2 = df_scaled.drop('Price', axis = 1)

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size = 0.2)

reg2 = linear_model.LinearRegression()

reg2.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
reg2.score(x_test2, y_test2)
# Out:
# 0.6984087706621797

# %%
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()
dfs2 = pd.DataFrame(sc.fit_transform(df), columns= df.columns)

# %%
y3 = df_scaled.Price

x3 = df_scaled.drop('Price', axis = 1)

x_train3, x_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size = 0.2)

reg3 = linear_model.LinearRegression()

reg3.fit(x_train3, y_train3)
# Out:
# LinearRegression()

# %%
reg3.score(x_test3, y_test3)
# Out:
# 0.708391170839167

# %% [markdown]
# Plotting some figures for the comparison between the initial and new(standardized) data set:

# %%
import matplotlib.pyplot as plt
df_scaled.hist()
plt.show()

# %%
import matplotlib.pyplot as plt
df.hist()
plt.show()

# %%
df_scaled.plot(kind='density',subplots=True,sharex=False)
plt.show()

# %%
df.plot(kind='density',subplots=True,sharex=False)
plt.show()

# %%
df_scaled.plot(kind='box',subplots=True,sharex=False,sharey=False)
# Out:
# Year                     AxesSubplot(0.125,0.125;0.0945122x0.755)
# Price                 AxesSubplot(0.238415,0.125;0.0945122x0.755)
# Объем двигателя, л    AxesSubplot(0.351829,0.125;0.0945122x0.755)
# Пробег                AxesSubplot(0.465244,0.125;0.0945122x0.755)
# Fuel                  AxesSubplot(0.578659,0.125;0.0945122x0.755)
# Body                  AxesSubplot(0.692073,0.125;0.0945122x0.755)
# brnd                  AxesSubplot(0.805488,0.125;0.0945122x0.755)
# dtype: object

# %%
df.plot(kind='box',subplots=True,sharex=False,sharey=False)
# Out:
# Year                     AxesSubplot(0.125,0.125;0.0945122x0.755)
# Price                 AxesSubplot(0.238415,0.125;0.0945122x0.755)
# Объем двигателя, л    AxesSubplot(0.351829,0.125;0.0945122x0.755)
# Пробег                AxesSubplot(0.465244,0.125;0.0945122x0.755)
# Fuel                  AxesSubplot(0.578659,0.125;0.0945122x0.755)
# Body                  AxesSubplot(0.692073,0.125;0.0945122x0.755)
# brnd                  AxesSubplot(0.805488,0.125;0.0945122x0.755)
# dtype: object

# %%
pd.plotting.scatter_matrix(df_scaled)
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Price', ylabel='Year'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Year'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Year'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Year'>,
#         <AxesSubplot:xlabel='Body', ylabel='Year'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Price'>,
#         <AxesSubplot:xlabel='Price', ylabel='Price'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Price'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Price'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Price'>,
#         <AxesSubplot:xlabel='Body', ylabel='Price'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Price'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Price', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Body', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Объем двигателя, л'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Price', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Body', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Пробег'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Price', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Body', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Fuel'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Body'>,
#         <AxesSubplot:xlabel='Price', ylabel='Body'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Body'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Body'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Body'>,
#         <AxesSubplot:xlabel='Body', ylabel='Body'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Body'>],
#        [<AxesSubplot:xlabel='Year', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Price', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Body', ylabel='brnd'>,
#         <AxesSubplot:xlabel='brnd', ylabel='brnd'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Price', ylabel='Year'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Year'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Year'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Year'>,
#         <AxesSubplot:xlabel='Body', ylabel='Year'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Price'>,
#         <AxesSubplot:xlabel='Price', ylabel='Price'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Price'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Price'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Price'>,
#         <AxesSubplot:xlabel='Body', ylabel='Price'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Price'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Price', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='Body', ylabel='Объем двигателя, л'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Объем двигателя, л'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Price', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='Body', ylabel='Пробег'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Пробег'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Price', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='Body', ylabel='Fuel'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Fuel'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Body'>,
#         <AxesSubplot:xlabel='Price', ylabel='Body'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='Body'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='Body'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='Body'>,
#         <AxesSubplot:xlabel='Body', ylabel='Body'>,
#         <AxesSubplot:xlabel='brnd', ylabel='Body'>],
#        [<AxesSubplot:xlabel='Year', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Price', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Объем двигателя, л', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Пробег', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Fuel', ylabel='brnd'>,
#         <AxesSubplot:xlabel='Body', ylabel='brnd'>,
#         <AxesSubplot:xlabel='brnd', ylabel='brnd'>]], dtype=object)

# %% [markdown]
# ## Conclusion
#
# 1. the initial = 0.6355199229563386
#
# 2. with standartization = 0.6984087706621797
#
# 3. with normalization = 0.708391170839167
#
#
# It is evident that with normalization it has highest precision and the initial is the lowest.
#
# By the end, we got plots for initial and final data set, but the models look almost the same.

# %% [markdown]
# ### If about grade,
#
# In my opinion my mark would be about 85-95.
